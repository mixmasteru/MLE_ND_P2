# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/NotebookVM/how-to-use-azureml/machine-learning-pipelines/intro-to-pipelines/aml-pipelines-with-automated-machine-learning-step.png)

# %% [markdown]
# # Azure Machine Learning Pipeline with AutoMLStep (Udacity Course 2)
# This notebook demonstrates the use of AutoMLStep in Azure Machine Learning Pipeline.

# %% [markdown]
# ## Introduction
# In this example we showcase how you can use AzureML Dataset to load data for AutoML via AML Pipeline.
#
# If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you have executed the [configuration](https://aka.ms/pl-config) before running this notebook.
#
# In this notebook you will learn how to:
# 1. Create an `Experiment` in an existing `Workspace`.
# 2. Create or Attach existing AmlCompute to a workspace.
# 3. Define data loading in a `TabularDataset`.
# 4. Configure AutoML using `AutoMLConfig`.
# 5. Use AutoMLStep
# 6. Train the model using AmlCompute
# 7. Explore the results.
# 8. Test the best fitted model.

# %% [markdown]
# ## Azure Machine Learning and Pipeline SDK-specific imports

# %%
import logging
import os
import csv

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Check core SDK version number
print("SDK version:", azureml.core.VERSION)
# Out:
# SDK version: 1.19.0

# %% [markdown]
# ## Initialize Workspace
# Initialize a workspace object from persisted configuration. Make sure the config file is present at .\config.json

# %%
ws = Workspace.from_config()
print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
# Out:
# quick-starts-ws-135207
# aml-quickstarts-135207
# southcentralus
# 5a4ab2ba-6c51-4805-8155-58759ad589d8

# %% [markdown]
# ## Create an Azure ML experiment
# Let's create an experiment named "automlstep-classification" and a folder to hold the training scripts. The script runs will be recorded under the experiment in Azure.
#
# The best practice is to use separate folders for scripts and its dependent files for each step and specify that folder as the `source_directory` for the step. This helps reduce the size of the snapshot created for the step (only the specific folder is snapshotted). Since changes in any files in the `source_directory` would trigger a re-upload of the snapshot, this helps keep the reuse of the step when there are no changes in the `source_directory` of the step.
#
# *Udacity Note:* There is no need to create an Azure ML experiment, this needs to re-use the experiment that was already created

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_name = 'Bank-marketing'
project_folder = './pipeline-project'

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Experiment(Name: Bank-marketing,
# Workspace: quick-starts-ws-135207)

# %% [markdown]
# ### Create or Attach an AmlCompute cluster
# You will need to create a [compute target](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#compute-target) for your AutoML run. In this tutorial, you get the default `AmlCompute` as your training compute resource.
#
# **Udacity Note** There is no need to create a new compute target, it can re-use the previous cluster

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "comp"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded
# AmlCompute wait for completion finished
#
# Minimum number of nodes requested have been provisioned

# %% [markdown]
# ## Data
#
# **Udacity note:** Make sure the `key` is the same name as the dataset that is uploaded, and that the description matches. If it is hard to find or unknown, loop over the `ws.datasets.keys()` and `print()` them.
# If it *isn't* found because it was deleted, it can be recreated with the link that has the CSV

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "Bank-marketing"
description_text = "Bank Marketing DataSet for Udacity Course 2"
ws = Workspace.from_config()
print(ws.datasets.keys())

if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        example_data = 'https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_train.csv'
        dataset = Dataset.Tabular.from_delimited_files(example_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
# KeysView({'Bank-marketing': DatasetRegistration(id='2d133e35-881f-4cc4-b795-8e8f9449a07b', name='Bank-marketing', version=1, description='Bank Marketing DataSet for Udacity Course 2', tags={})})
#                 age      duration      campaign         pdays      previous  \
# count  32950.000000  32950.000000  32950.000000  32950.000000  32950.000000
# mean      40.040212    257.335205      2.561730    962.174780      0.174780
# std       10.432313    257.331700      2.763646    187.646785      0.496503
# min       17.000000      0.000000      1.000000      0.000000      0.000000
# 25%       32.000000    102.000000      1.000000    999.000000      0.000000
# 50%       38.000000    179.000000      2.000000    999.000000      0.000000
# 75%       47.000000    318.000000      3.000000    999.000000      0.000000
# max       98.000000   4918.000000     56.000000    999.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  32950.000000    32950.000000   32950.000000  32950.000000  32950.000000
# mean       0.076228       93.574243     -40.518680      3.615654   5166.859608
# std        1.572242        0.578636       4.623004      1.735748     72.208448
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000

# %% [markdown]
# ### Review the Dataset Result
#
# You can peek the result of a TabularDataset at any range using `skip(i)` and `take(j).to_pandas_dataframe()`. Doing so evaluates only `j` records for all the steps in the TabularDataset, which makes it fast even against large datasets.
#
# `TabularDataset` objects are composed of a list of transformation steps (optional).

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#    age          job  marital    education  default housing loan    contact  \
# 0   57   technician  married  high.school       no      no  yes   cellular
# 1   55      unknown  married      unknown  unknown     yes   no  telephone
# 2   33  blue-collar  married     basic.9y       no      no   no   cellular
# 3   36       admin.  married  high.school       no      no   no  telephone
# 4   27    housemaid  married  high.school       no     yes   no   cellular
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         1      failure         -1.8
# 1   may         thu  ...         2    999         0  nonexistent          1.1
# 2   may         fri  ...         1    999         1      failure         -1.8
# 3   jun         fri  ...         4    999         0  nonexistent          1.4
# 4   jul         fri  ...         2    999         0  nonexistent          1.4
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          92.893          -46.2      1.299       5099.1  no
# 1          93.994          -36.4      4.860       5191.0  no
# 2          92.893          -46.2      1.313       5099.1  no
# 3          94.465          -41.8      4.967       5228.1  no
# 4          93.918          -42.7      4.963       5228.1  no
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Train
# This creates a general AutoML settings object.
# **Udacity notes:** These inputs must match what was used when training in the portal. `label_column_name` has to be `y` for example.

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 5,
    "primary_metric" : 'AUC_weighted'
}
automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="y",   
                             path = project_folder,
                             enable_early_stopping= True,
                             featurization= 'auto',
                             debug_log = "automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# #### Create Pipeline and AutoMLStep
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()
metrics_output_name = 'metrics_output'
best_model_output_name = 'best_model_output'

metrics_data = PipelineData(name='metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step automl_module [4acdeff9][6dfa8fda-930c-4b6c-a11b-4ca461b790e2], (This step will run and generate new outputs)
# Submitted PipelineRun 5d254d7b-c4ce-41a0-b804-537a399329b2
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Bank-marketing/runs/5d254d7b-c4ce-41a0-b804-537a399329b2?wsid=/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourcegroups/aml-quickstarts-135207/workspaces/quick-starts-ws-135207

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: 5d254d7b-c4ce-41a0-b804-537a399329b2
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Bank-marketing/runs/5d254d7b-c4ce-41a0-b804-537a399329b2?wsid=/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourcegroups/aml-quickstarts-135207/workspaces/quick-starts-ws-135207
# PipelineRun Status: Running
#
#
# StepRunId: 0298622f-105c-48dd-a4a3-fa05fe4b0e9c
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/Bank-marketing/runs/0298622f-105c-48dd-a4a3-fa05fe4b0e9c?wsid=/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourcegroups/aml-quickstarts-135207/workspaces/quick-starts-ws-135207
# StepRun( automl_module ) Status: NotStarted
# StepRun( automl_module ) Status: Running
#
# StepRun(automl_module) Execution Summary
# =========================================
# StepRun( automl_module ) Status: Finished
# {'runId': '0298622f-105c-48dd-a4a3-fa05fe4b0e9c', 'target': 'comp', 'status': 'Completed', 'startTimeUtc': '2021-01-18T14:45:39.695508Z', 'endTimeUtc': '2021-01-18T15:16:19.076861Z', 'properties': {'azureml.runsource': 'azureml.StepRun', 'ContentSnapshotId': 'fcb412ef-b0a9-406a-bebc-006e9a5b6fc1', 'StepType': 'AutoMLStep', 'azureml.moduleid': '6dfa8fda-930c-4b6c-a11b-4ca461b790e2', 'azureml.nodeid': '4acdeff9', 'azureml.pipelinerunid': '5d254d7b-c4ce-41a0-b804-537a399329b2', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'AUC_weighted', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': None, 'target': 'comp', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "5a4ab2ba-6c51-4805-8155-58759ad589d8", "resource_group": "aml-quickstarts-135207", "workspace_name": "quick-starts-ws-135207", "region": "southcentralus", "compute_target": "comp", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "iterations": 1000, "primary_metric": "AUC_weighted", "task_type": "classification", "data_script": null, "validation_size": 0.0, "n_cross_validations": null, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 5, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["TensorFlowLinearClassifier", "TensorFlowDNN", "KNN", "MultinomialNaiveBayes", "XGBoostClassifier", "LinearSVM", "SGD", "GradientBoosting", "RandomForest", "BernoulliNaiveBayes", "SVM", "LogisticRegression", "DecisionTree", "ExtremeRandomTrees", "AveragedPerceptronClassifier", "LightGBM"], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "SDK-1.13.0", "environment_label": null, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "metrics": null, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "y", "weight_column_name": null, "cv_split_column_names": null, "enable_local_managed": false, "_local_managed_run_id": null, "cost_mode": 1, "lag_length": 0, "metric_operation": "maximize", "preprocess": true}', 'DataPrepJsonString': '{\\"training_data\\": {\\"datasetId\\": \\"2d133e35-881f-4cc4-b795-8e8f9449a07b\\"}, \\"datasets\\": 0}', 'EnableSubsampling': 'False', 'runTemplate': 'AutoML', 'Orchestrator': 'automl', 'ClientType': 'Others', '_aml_system_scenario_identification': 'Remote.Parent', 'root_attribution': 'azureml.StepRun', 'snapshotId': 'fcb412ef-b0a9-406a-bebc-006e9a5b6fc1', 'SetupRunId': '0298622f-105c-48dd-a4a3-fa05fe4b0e9c_setup', 'SetupRunContainerId': 'dcid.0298622f-105c-48dd-a4a3-fa05fe4b0e9c_setup', 'ClientSdkVersion': '1.19.0', 'FeaturizationRunJsonPath': 'featurizer_container.json', 'FeaturizationRunId': '0298622f-105c-48dd-a4a3-fa05fe4b0e9c_featurize', 'ProblemInfoJsonString': '{"dataset_num_categorical": 0, "is_sparse": true, "subsampling": false, "dataset_classes": 2, " ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '5d254d7b-c4ce-41a0-b804-537a399329b2', 'status': 'Completed', 'startTimeUtc': '2021-01-18T14:45:14.762154Z', 'endTimeUtc': '2021-01-18T15:17:43.253194Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://mlstrg135207.blob.core.windows.net/azureml/ExperimentRun/dcid.5d254d7b-c4ce-41a0-b804-537a399329b2/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=Ll%2ByKCu1BVLzjogiHyif56wQMh0fr6Suu%2BzxkEIog8I%3D&st=2021-01-18T14%3A35%3A18Z&se=2021-01-18T22%3A45%3A18Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://mlstrg135207.blob.core.windows.net/azureml/ExperimentRun/dcid.5d254d7b-c4ce-41a0-b804-537a399329b2/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=emMloDGkfHmdZ9qsEE%2BnHLbxw9UV2jP%2BlNk6hssADk8%3D&st=2021-01-18T14%3A35%3A18Z&se=2021-01-18T22%3A45%3A18Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://mlstrg135207.blob.core.windows.net/azureml/ExperimentRun/dcid.5d254d7b-c4ce-41a0-b804-537a399329b2/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=m1iAWYD4rlztFCwHZE9rHziAiivArO9QhqvPazH0Yxw%3D&st=2021-01-18T14%3A35%3A18Z&se=2021-01-18T22%3A45%3A18Z&sp=r'}}
# 'Finished'

# %% [markdown]
# ## Examine Results
#
# ### Retrieve the metrics of all child runs
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('.', show_progress=True)
# Out:
# Downloading azureml/0298622f-105c-48dd-a4a3-fa05fe4b0e9c/metrics_data
# Downloaded azureml/0298622f-105c-48dd-a4a3-fa05fe4b0e9c/metrics_data, 1 files out of an estimated total of 1

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_13  \
# precision_score_micro                               [0.9062215477996965]
# f1_score_macro                                      [0.6650154684677185]
# recall_score_weighted                               [0.9062215477996965]
# AUC_weighted                                        [0.9308878256246675]
# precision_score_macro                                [0.822098675416211]
# AUC_macro                                           [0.9308878256246677]
# AUC_micro                                           [0.9758990146932517]
# f1_score_micro                                      [0.9062215477996965]
# balanced_accuracy                                   [0.6227454260188535]
# matthews_correlation                                [0.3976739324324451]
# recall_score_micro                                  [0.9062215477996965]
# norm_macro_recall                                  [0.24549085203770704]
# weighted_accuracy                                   [0.9766010009385309]
# recall_score_macro                                  [0.6227454260188535]
# average_precision_score_weighted                     [0.947605275820125]
# log_loss                                           [0.33655623030329523]
# average_precision_score_macro                       [0.7985126174047921]
# average_precision_score_micro                       [0.9766643355999638]
# accuracy                                            [0.9062215477996965]
# precision_score_weighted                            [0.8929725418691179]
# f1_score_weighted                                    [0.885603431576398]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_25  \
# precision_score_micro                               [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_weighted                               [0.8880121396054628]
# AUC_weighted                                        [0.9333274057279194]
# precision_score_macro                               [0.4440060698027314]
# AUC_macro                                           [0.9333274057279193]
# AUC_micro                                           [0.9741979962282485]
# f1_score_micro                                      [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# matthews_correlation                                               [0.0]
# recall_score_micro                                  [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# recall_score_macro                                                 [0.5]
# average_precision_score_weighted                    [0.9484016509301396]
# log_loss                                           [0.24154115274004728]
# average_precision_score_macro                       [0.7996165142711693]
# average_precision_score_micro                       [0.9754907705763335]
# accuracy                                            [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_6  \
# precision_score_micro                              [0.8995447647951441]
# f1_score_macro                                     [0.6200834695056934]
# recall_score_weighted                              [0.8995447647951441]
# AUC_weighted                                       [0.8786327422399309]
# precision_score_macro                              [0.7980516431924882]
# AUC_macro                                          [0.8786327422399309]
# AUC_micro                                           [0.963724316744228]
# f1_score_micro                                     [0.8995447647951441]
# balanced_accuracy                                  [0.5881986007146469]
# matthews_correlation                              [0.32426987445816596]
# recall_score_micro                                 [0.8995447647951441]
# norm_macro_recall                                 [0.17639720142929383]
# weighted_accuracy                                  [0.9768435955650944]
# recall_score_macro                                 [0.5881986007146469]
# average_precision_score_weighted                   [0.9267564318046448]
# log_loss                                           [0.2560323869813926]
# average_precision_score_macro                      [0.7334492065867536]
# average_precision_score_micro                      [0.9647033554320988]
# accuracy                                           [0.8995447647951441]
# precision_score_weighted                           [0.8819023417184951]
# f1_score_weighted                                  [0.8729435303886112]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_2  \
# precision_score_micro                              [0.8928679817905918]
# f1_score_macro                                     [0.5335071816716472]
# recall_score_weighted                              [0.8928679817905918]
# AUC_weighted                                       [0.8977622363373327]
# precision_score_macro                              [0.8149025019391382]
# AUC_macro                                          [0.8977622363373325]
# AUC_micro                                          [0.9672659867689354]
# f1_score_micro                                     [0.8928679817905918]
# balanced_accuracy                                  [0.5323374030049255]
# matthews_correlation                              [0.20182298295749404]
# recall_score_micro                                 [0.8928679817905918]
# norm_macro_recall                                 [0.06467480600985098]
# weighted_accuracy                                  [0.9823779723159292]
# recall_score_macro                                 [0.5323374030049255]
# average_precision_score_weighted                   [0.9309110414130851]
# log_loss                                          [0.24058587457870992]
# average_precision_score_macro                      [0.7452755888819335]
# average_precision_score_micro                      [0.9673832828722468]
# accuracy                                           [0.8928679817905918]
# precision_score_weighted                           [0.8766805409785454]
# f1_score_weighted                                  [0.8512407798404374]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_30  \
# precision_score_micro                               [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_weighted                               [0.8880121396054628]
# AUC_weighted                                         [0.934374461653024]
# precision_score_macro                               [0.4440060698027314]
# AUC_macro                                           [0.9343744616530238]
# AUC_micro                                           [0.9744062484888817]
# f1_score_micro                                      [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# matthews_correlation                                               [0.0]
# recall_score_micro                                  [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# recall_score_macro                                                 [0.5]
# average_precision_score_weighted                     [0.948588659974036]
# log_loss                                           [0.29313359336803707]
# average_precision_score_macro                       [0.8004617629290862]
# average_precision_score_micro                       [0.9755997293287618]
# accuracy                                            [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_9  \
# precision_score_micro                               [0.743247344461305]
# f1_score_macro                                     [0.6139300778796006]
# recall_score_weighted                               [0.743247344461305]
# AUC_weighted                                       [0.8224533988333732]
# precision_score_macro                              [0.6114445051922092]
# AUC_macro                                          [0.8224533988333731]
# AUC_micro                                          [0.8212379542277926]
# f1_score_micro                                      [0.743247344461305]
# balanced_accuracy                                  [0.7393891232145404]
# matthews_correlation                              [0.32667171524355304]
# recall_score_micro                                  [0.743247344461305]
# norm_macro_recall                                 [0.47877824642908084]
# weighted_accuracy                                  [0.7442052364337578]
# recall_score_macro                                 [0.7393891232145404]
# average_precision_score_weighted                   [0.9102925866042256]
# log_loss                                           [0.5578990780491087]
# average_precision_score_macro                      [0.7039189576358307]
# average_precision_score_micro                      [0.7900441990138165]
# accuracy                                            [0.743247344461305]
# precision_score_weighted                           [0.8795589522972832]
# f1_score_weighted                                  [0.7873250703543873]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_21  \
# precision_score_micro                               [0.9125948406676783]
# f1_score_macro                                      [0.7613817409356443]
# recall_score_weighted                               [0.9125948406676783]
# AUC_weighted                                        [0.9424512871239444]
# precision_score_macro                               [0.7872528061629692]
# AUC_macro                                           [0.9424512871239443]
# AUC_micro                                           [0.9790159827392864]
# f1_score_micro                                      [0.9125948406676783]
# balanced_accuracy                                   [0.7411947273949842]
# matthews_correlation                                [0.5264365575296669]
# recall_score_micro                                  [0.9125948406676783]
# norm_macro_recall                                   [0.4823894547899683]
# weighted_accuracy                                    [0.955148852498673]
# recall_score_macro                                  [0.7411947273949842]
# average_precision_score_weighted                    [0.9524536910133203]
# log_loss                                           [0.18386077817913915]
# average_precision_score_macro                       [0.8131628841963428]
# average_precision_score_micro                       [0.9800107530929907]
# accuracy                                            [0.9125948406676783]
# precision_score_weighted                            [0.9064419404986112]
# f1_score_weighted                                   [0.9087900123862012]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_3  \
# precision_score_micro                              [0.7993930197268588]
# f1_score_macro                                     [0.6681828520831019]
# recall_score_weighted                              [0.7993930197268588]
# AUC_weighted                                       [0.8882701950737896]
# precision_score_macro                              [0.6464945068967204]
# AUC_macro                                          [0.8882701950737895]
# AUC_micro                                          [0.8730448718686749]
# f1_score_micro                                     [0.7993930197268588]
# balanced_accuracy                                  [0.7828435649359912]
# matthews_correlation                              [0.40711191863765694]
# recall_score_micro                                 [0.7993930197268588]
# norm_macro_recall                                  [0.5656871298719823]
# weighted_accuracy                                  [0.8035018016962538]
# recall_score_macro                                 [0.7828435649359912]
# average_precision_score_weighted                   [0.9333621819154393]
# log_loss                                           [0.5087980358577068]
# average_precision_score_macro                      [0.7558828934214779]
# average_precision_score_micro                      [0.8592472077061796]
# accuracy                                           [0.7993930197268588]
# precision_score_weighted                           [0.8928470571844734]
# f1_score_weighted                                  [0.8301058244118117]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_26  \
# precision_score_micro                               [0.9074355083459787]
# f1_score_macro                                      [0.6969780573488569]
# recall_score_weighted                               [0.9074355083459787]
# AUC_weighted                                        [0.9350098268583507]
# precision_score_macro                               [0.7992420189049403]
# AUC_macro                                           [0.9350098268583507]
# AUC_micro                                           [0.9771930155820769]
# f1_score_micro                                      [0.9074355083459787]
# balanced_accuracy                                   [0.6554005116264423]
# matthews_correlation                               [0.43128813031641494]
# recall_score_micro                                  [0.9074355083459787]
# norm_macro_recall                                   [0.3108010232528846]
# weighted_accuracy                                   [0.9700089806001332]
# recall_score_macro                                  [0.6554005116264423]
# average_precision_score_weighted                    [0.9499966225005592]
# log_loss                                            [0.3304940796991938]
# average_precision_score_macro                       [0.8063549152507894]
# average_precision_score_micro                       [0.9781626875518643]
# accuracy                                            [0.9074355083459787]
# precision_score_weighted                            [0.8935012190755486]
# f1_score_weighted                                   [0.8929502722795345]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_23  ...  \
# precision_score_micro                               [0.9104704097116844]  ...
# f1_score_macro                                      [0.7571819946586409]  ...
# recall_score_weighted                               [0.9104704097116844]  ...
# AUC_weighted                                        [0.9410393129905327]  ...
# precision_score_macro                               [0.7802691533441449]  ...
# AUC_macro                                           [0.9410393129905326]  ...
# AUC_micro                                           [0.9787503482768071]  ...
# f1_score_micro                                      [0.9104704097116844]  ...
# balanced_accuracy                                    [0.738814423345874]  ...
# matthews_correlation                                [0.5174256129629391]  ...
# recall_score_micro                                  [0.9104704097116844]  ...
# norm_macro_recall                                    [0.477628846691748]  ...
# weighted_accuracy                                   [0.9530879479104497]  ...
# recall_score_macro                                   [0.738814423345874]  ...
# average_precision_score_weighted                    [0.9522580543753243]  ...
# log_loss                                           [0.18600765802920322]  ...
# average_precision_score_macro                       [0.8129801475093046]  ...
# average_precision_score_micro                       [0.9797562823129949]  ...
# accuracy                                            [0.9104704097116844]  ...
# precision_score_weighted                             [0.904541125173857]  ...
# f1_score_weighted                                   [0.9068987545099138]  ...
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_29  \
# precision_score_micro                               [0.9144157814871017]
# f1_score_macro                                      [0.7657346712384026]
# recall_score_weighted                               [0.9144157814871017]
# AUC_weighted                                        [0.9432181710743972]
# precision_score_macro                                [0.793034019312157]
# AUC_macro                                           [0.9432181710743972]
# AUC_micro                                            [0.979231511394696]
# f1_score_micro                                      [0.9144157814871017]
# balanced_accuracy                                   [0.7445882814945717]
# matthews_correlation                                [0.5354351023345689]
# recall_score_micro                                  [0.9144157814871017]
# norm_macro_recall                                  [0.48917656298914336]
# weighted_accuracy                                   [0.9565793559791012]
# recall_score_macro                                  [0.7445882814945717]
# average_precision_score_weighted                     [0.952863439136161]
# log_loss                                            [0.1831640145226401]
# average_precision_score_macro                       [0.8146709985876289]
# average_precision_score_micro                       [0.9802073332256549]
# accuracy                                            [0.9144157814871017]
# precision_score_weighted                            [0.9082858447415418]
# f1_score_weighted                                   [0.9105642327263734]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_39  \
# precision_score_micro                               [0.9125948406676783]
# f1_score_macro                                      [0.7555577536536513]
# recall_score_weighted                               [0.9125948406676783]
# AUC_weighted                                        [0.9453465518934069]
# precision_score_macro                               [0.7901556216121699]
# AUC_macro                                           [0.9453465518934069]
# AUC_micro                                           [0.9798390443054152]
# f1_score_micro                                      [0.9125948406676783]
# balanced_accuracy                                   [0.7305375411922267]
# matthews_correlation                                 [0.517268841395156]
# recall_score_micro                                  [0.9125948406676783]
# norm_macro_recall                                   [0.4610750823844534]
# weighted_accuracy                                   [0.9577947435608085]
# recall_score_macro                                  [0.7305375411922267]
# average_precision_score_weighted                    [0.9539284298559535]
# log_loss                                            [0.2018483732342096]
# average_precision_score_macro                       [0.8183668226933671]
# average_precision_score_micro                       [0.9807910335056388]
# accuracy                                            [0.9125948406676783]
# precision_score_weighted                            [0.9050462943185681]
# f1_score_weighted                                   [0.9076000980288377]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_15  \
# precision_score_micro                               [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_weighted                               [0.8880121396054628]
# AUC_weighted                                        [0.8850655833967772]
# precision_score_macro                               [0.4440060698027314]
# AUC_macro                                           [0.8850655833967772]
# AUC_micro                                           [0.9645990499238972]
# f1_score_micro                                      [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# matthews_correlation                                               [0.0]
# recall_score_micro                                  [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# recall_score_macro                                                 [0.5]
# average_precision_score_weighted                    [0.9211676854690085]
# log_loss                                             [0.257999280600051]
# average_precision_score_macro                       [0.7031766750634804]
# average_precision_score_micro                       [0.9654796535281517]
# accuracy                                            [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_17  \
# precision_score_micro                               [0.7660091047040971]
# f1_score_macro                                        [0.63501183633177]
# recall_score_weighted                               [0.7660091047040971]
# AUC_weighted                                        [0.8419705027535579]
# precision_score_macro                                [0.624373020655125]
# AUC_macro                                            [0.841970502753558]
# AUC_micro                                           [0.8426441865980783]
# f1_score_micro                                      [0.7660091047040971]
# balanced_accuracy                                   [0.7569417816529498]
# matthews_correlation                                [0.3575283234468954]
# recall_score_micro                                  [0.7660091047040971]
# norm_macro_recall                                   [0.5138835633058996]
# weighted_accuracy                                   [0.7682602757507585]
# recall_score_macro                                  [0.7569417816529498]
# average_precision_score_weighted                    [0.9157888581172452]
# log_loss                                            [0.5619249145078696]
# average_precision_score_macro                       [0.7119741431990118]
# average_precision_score_micro                       [0.8187698526647724]
# accuracy                                            [0.7660091047040971]
# precision_score_weighted                            [0.8847349666746948]
# f1_score_weighted                                   [0.8046977609660355]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_22  \
# precision_score_micro                               [0.9128983308042489]
# f1_score_macro                                      [0.7668111420906795]
# recall_score_weighted                               [0.9128983308042489]
# AUC_weighted                                        [0.9448491887516278]
# precision_score_macro                               [0.7860811293290488]
# AUC_macro                                           [0.9448491887516277]
# AUC_micro                                           [0.9793693944704005]
# f1_score_micro                                      [0.9128983308042489]
# balanced_accuracy                                   [0.7508386635472644]
# matthews_correlation                                [0.5357619178216784]
# recall_score_micro                                  [0.9128983308042489]
# norm_macro_recall                                   [0.5016773270945287]
# weighted_accuracy                                   [0.9531333625443325]
# recall_score_macro                                  [0.7508386635472644]
# average_precision_score_weighted                    [0.9516860732237478]
# log_loss                                           [0.18115151864375498]
# average_precision_score_macro                       [0.8085204474402641]
# average_precision_score_micro                        [0.980352027134298]
# accuracy                                            [0.9128983308042489]
# precision_score_weighted                            [0.9080335867085474]
# f1_score_weighted                                   [0.9100415644605403]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_27  \
# precision_score_micro                               [0.9092564491654022]
# f1_score_macro                                      [0.7595316113521396]
# recall_score_weighted                               [0.9092564491654022]
# AUC_weighted                                        [0.9424661061374797]
# precision_score_macro                               [0.7748834066540344]
# AUC_macro                                           [0.9424661061374797]
# AUC_micro                                            [0.978479463757337]
# f1_score_micro                                       [0.909256449165402]
# balanced_accuracy                                   [0.7464198189487021]
# matthews_correlation                                [0.5205255778525764]
# recall_score_micro                                  [0.9092564491654022]
# norm_macro_recall                                  [0.49283963789740426]
# weighted_accuracy                                   [0.9496843797918908]
# recall_score_macro                                  [0.7464198189487021]
# average_precision_score_weighted                    [0.9507406492420406]
# log_loss                                           [0.18954575118674993]
# average_precision_score_macro                       [0.8055691338726518]
# average_precision_score_micro                       [0.9794837679800324]
# accuracy                                            [0.9092564491654022]
# precision_score_weighted                            [0.9048841140704427]
# f1_score_weighted                                   [0.9067802306938751]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_14  \
# precision_score_micro                               [0.8880121396054628]
# f1_score_macro                                      [0.4703423886834914]
# recall_score_weighted                               [0.8880121396054628]
# AUC_weighted                                        [0.8926885765781786]
# precision_score_macro                               [0.4440060698027314]
# AUC_macro                                           [0.8926885765781786]
# AUC_micro                                           [0.9661152111190682]
# f1_score_micro                                      [0.8880121396054628]
# balanced_accuracy                                                  [0.5]
# matthews_correlation                                               [0.0]
# recall_score_micro                                  [0.8880121396054628]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9843450583187134]
# recall_score_macro                                                 [0.5]
# average_precision_score_weighted                    [0.9301644573185838]
# log_loss                                            [0.2660215229069049]
# average_precision_score_macro                       [0.7487556842167268]
# average_precision_score_micro                        [0.965380469712414]
# accuracy                                            [0.8880121396054628]
# precision_score_weighted                             [0.788565560086672]
# f1_score_weighted                                   [0.8353395018439429]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_19  \
# precision_score_micro                               [0.9101669195751139]
# f1_score_macro                                      [0.7566770849549538]
# recall_score_weighted                               [0.9101669195751139]
# AUC_weighted                                        [0.9396755006511105]
# precision_score_macro                               [0.7792557284588055]
# AUC_macro                                           [0.9396755006511104]
# AUC_micro                                           [0.9784093708911972]
# f1_score_micro                                      [0.9101669195751139]
# balanced_accuracy                                   [0.7386435415960448]
# matthews_correlation                                 [0.516304468508235]
# recall_score_micro                                  [0.9101669195751139]
# norm_macro_recall                                   [0.4772870831920897]
# weighted_accuracy                                   [0.9527515346984474]
# recall_score_macro                                  [0.7386435415960448]
# average_precision_score_weighted                    [0.9520327752925208]
# log_loss                                            [0.2102510113682131]
# average_precision_score_macro                       [0.8128212119523119]
# average_precision_score_micro                       [0.9794050745834078]
# accuracy                                            [0.9101669195751139]
# precision_score_weighted                            [0.9042986554981781]
# f1_score_weighted                                   [0.9066478557320837]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_20  \
# precision_score_micro                               [0.9122913505311078]
# f1_score_macro                                      [0.7639708800214947]
# recall_score_weighted                               [0.9122913505311078]
# AUC_weighted                                         [0.944301811439167]
# precision_score_macro                               [0.7848448881130385]
# AUC_macro                                            [0.944301811439167]
# AUC_micro                                           [0.9794106580762224]
# f1_score_micro                                      [0.9122913505311078]
# balanced_accuracy                                   [0.7469445046466869]
# matthews_correlation                                [0.5304371020063181]
# recall_score_micro                                  [0.9122913505311078]
# norm_macro_recall                                  [0.49388900929337387]
# weighted_accuracy                                   [0.9533424998077065]
# recall_score_macro                                  [0.7469445046466869]
# average_precision_score_weighted                    [0.9536247356317944]
# log_loss                                            [0.1797588514357173]
# average_precision_score_macro                       [0.8174690988547908]
# average_precision_score_micro                       [0.9803953057992305]
# accuracy                                            [0.9122913505311078]
# precision_score_weighted                            [0.9070348410200512]
# f1_score_weighted                                   [0.9091682165808672]
#
#                                  0298622f-105c-48dd-a4a3-fa05fe4b0e9c_31
# precision_score_micro                               [0.9122913505311078]
# f1_score_macro                                      [0.7693286329671437]
# recall_score_weighted                               [0.9122913505311078]
# AUC_weighted                                        [0.9426541223717092]
# precision_score_macro                               [0.7827350576792489]
# AUC_macro                                           [0.9426541223717091]
# AUC_micro                                           [0.9789525215240823]
# f1_score_micro                                      [0.9122913505311078]
# balanced_accuracy                                   [0.7576016908494444]
# matthews_correlation                                [0.5397519019719696]
# recall_score_micro                                  [0.9122913505311078]
# norm_macro_recall                                   [0.5152033816988888]
# weighted_accuracy                                   [0.9506966087455709]
# recall_score_macro                                  [0.7576016908494444]
# average_precision_score_weighted                    [0.9538276116343758]
# log_loss                                           [0.18898047296696532]
# average_precision_score_macro                        [0.819540069814724]
# average_precision_score_micro                       [0.9798987798270309]
# accuracy                                            [0.9122913505311078]
# precision_score_weighted                            [0.9086474259126974]
# f1_score_weighted                                   [0.9102521752998562]
#
# [21 rows x 37 columns]

# %% [markdown]
# ### Retrieve the Best Model

# %%
# Retrieve best model from Pipeline Run
best_model_output = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model_output.download('.', show_progress=True)
# Out:
# Downloading azureml/0298622f-105c-48dd-a4a3-fa05fe4b0e9c/model_data
# Downloaded azureml/0298622f-105c-48dd-a4a3-fa05fe4b0e9c/model_data, 1 files out of an estimated total of 1

# %%
import pickle

with open(best_model_output._path_on_datastore, "rb" ) as f:
    best_model = pickle.load(f)
best_model
# Out:
# PipelineWithYTransformations(Pipeline={'memory': None,
#                                        'steps': [('datatransformer',
#                                                   DataTransformer(enable_dnn=None,
#                                                                   enable_feature_sweeping=None,
#                                                                   feature_sweeping_config=None,
#                                                                   feature_sweeping_timeout=None,
#                                                                   featurization_config=None,
#                                                                   force_text_dnn=None,
#                                                                   is_cross_validation=None,
#                                                                   is_onnx_compatible=None,
#                                                                   logger=None,
#                                                                   observer=None,
#                                                                   task=None,
#                                                                   working_dir=None))...
#                                                                                                                                  reg_alpha=0.6842105263157894,
#                                                                                                                                  reg_lambda=1,
#                                                                                                                                  silent=True,
#                                                                                                                                  subsample=0.6931578947368422,
#                                                                                                                                  subsample_for_bin=200000,
#                                                                                                                                  subsample_freq=0,
#                                                                                                                                  verbose=-10))],
#                                                                                                       verbose=False))],
#                                                                                 flatten_transform=None,
#                                                                                 weights=[0.26666666666666666,
#                                                                                          0.06666666666666667,
#                                                                                          0.06666666666666667,
#                                                                                          0.13333333333333333,
#                                                                                          0.06666666666666667,
#                                                                                          0.2,
#                                                                                          0.2]))],
#                                        'verbose': False},
#                              y_transformer={},
#                              y_transformer_name='LabelEncoder')

# %%
best_model.steps
# Out:
# [('datatransformer',
#   DataTransformer(enable_dnn=None, enable_feature_sweeping=None,
#                   feature_sweeping_config=None, feature_sweeping_timeout=None,
#                   featurization_config=None, force_text_dnn=None,
#                   is_cross_validation=None, is_onnx_compatible=None, logger=None,
#                   observer=None, task=None, working_dir=None)),
#  ('prefittedsoftvotingclassifier',
#   PreFittedSoftVotingClassifier(classification_labels=None,
#                                 estimators=[('0',
#                                              Pipeline(memory=None,
#                                                       steps=[('maxabsscaler',
#                                                               MaxAbsScaler(copy=True)),
#                                                              ('lightgbmclassifier',
#                                                               LightGBMClassifier(boosting_type='gbdt',
#                                                                                  class_weight=None,
#                                                                                  colsample_bytree=1.0,
#                                                                                  importance_type='split',
#                                                                                  learning_rate=0.1,
#                                                                                  max_depth=-1,
#                                                                                  min_child_samples=20,
#                                                                                  min_child_weight=0.001,
#                                                                                  min_spl...
#                                                                                  n_jobs=1,
#                                                                                  num_leaves=107,
#                                                                                  objective=None,
#                                                                                  random_state=None,
#                                                                                  reg_alpha=0.6842105263157894,
#                                                                                  reg_lambda=1,
#                                                                                  silent=True,
#                                                                                  subsample=0.6931578947368422,
#                                                                                  subsample_for_bin=200000,
#                                                                                  subsample_freq=0,
#                                                                                  verbose=-10))],
#                                                       verbose=False))],
#                                 flatten_transform=None,
#                                 weights=[0.26666666666666666, 0.06666666666666667,
#                                          0.06666666666666667, 0.13333333333333333,
#                                          0.06666666666666667, 0.2, 0.2]))]

# %% [markdown]
# ### Test the Model
# #### Load Test Data
# For the test data, it should have the same preparation step as the train data. Otherwise it might get failed at the preprocessing step.

# %%
dataset_test = Dataset.Tabular.from_delimited_files(path='https://automlsamplenotebookdata.blob.core.windows.net/automl-sample-notebook-data/bankmarketing_test.csv')
df_test = dataset_test.to_pandas_dataframe()
df_test = df_test[pd.notnull(df_test['y'])]

y_test = df_test['y']
X_test = df_test.drop(['y'], axis=1)

# %% [markdown]
# #### Testing Our Best Fitted Model
#
# We will use confusion matrix to see how our model works.

# %%
from sklearn.metrics import confusion_matrix
ypred = best_model.predict(X_test)
cm = confusion_matrix(y_test, ypred)

# %%
# Visualize the confusion matrix
pd.DataFrame(cm).style.background_gradient(cmap='Blues', low=0, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_c25acb16_59a1_11eb_94df_f988cb198592row0_col0 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }    #T_c25acb16_59a1_11eb_94df_f988cb198592row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c25acb16_59a1_11eb_94df_f988cb198592row1_col0 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_c25acb16_59a1_11eb_94df_f988cb198592row1_col1 {
#             background-color:  #63a8d3;
#             color:  #000000;
#         }</style><table id="T_c25acb16_59a1_11eb_94df_f988cb198592" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c25acb16_59a1_11eb_94df_f988cb198592level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c25acb16_59a1_11eb_94df_f988cb198592row0_col0" class="data row0 col0" >3551</td>
#                         <td id="T_c25acb16_59a1_11eb_94df_f988cb198592row0_col1" class="data row0 col1" >85</td>
#             </tr>
#             <tr>
#                         <th id="T_c25acb16_59a1_11eb_94df_f988cb198592level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c25acb16_59a1_11eb_94df_f988cb198592row1_col0" class="data row1 col0" >267</td>
#                         <td id="T_c25acb16_59a1_11eb_94df_f988cb198592row1_col1" class="data row1 col1" >217</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## Publish and run from REST endpoint
#
# Run the following code to publish the pipeline to your workspace. In your workspace in the portal, you can see metadata for the pipeline including run history and durations. You can also run the pipeline manually from the portal.
#
# Additionally, publishing the pipeline enables a REST endpoint to rerun the pipeline from any HTTP library on any platform.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name="Bankmarketing Train", description="Training bankmarketing pipeline", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: Bankmarketing Train,
# Id: e83e7ab4-d1a8-44cb-9afb-4ad4708af0db,
# Status: Active,
# Endpoint: https://southcentralus.api.azureml.ms/pipelines/v1.0/subscriptions/5a4ab2ba-6c51-4805-8155-58759ad589d8/resourceGroups/aml-quickstarts-135207/providers/Microsoft.MachineLearningServices/workspaces/quick-starts-ws-135207/PipelineRuns/PipelineSubmit/e83e7ab4-d1a8-44cb-9afb-4ad4708af0db)

# %% [markdown]
# Authenticate once again, to retrieve the `auth_header` so that the endpoint can be used

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()

# %% [markdown]
# Get the REST url from the endpoint property of the published pipeline object. You can also find the REST url in your workspace in the portal. Build an HTTP POST request to the endpoint, specifying your authentication header. Additionally, add a JSON payload object with the experiment name and the batch size parameter. As a reminder, the process_count_per_node is passed through to ParallelRunStep because you defined it is defined as a PipelineParameter object in the step configuration.
#
# Make the request to trigger the run. Access the Id key from the response dict to get the value of the run id.

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "pipeline-rest-endpoint"}
                        )

# %%
try:
    response.raise_for_status()
except Exception:    
    raise Exception("Received bad response from the endpoint: {}\n"
                    "Response Code: {}\n"
                    "Headers: {}\n"
                    "Content: {}".format(rest_endpoint, response.status_code, response.headers, response.content))

run_id = response.json().get('Id')
print('Submitted pipeline run: ', run_id)
# Out:
# Submitted pipeline run:  8b410dfc-235b-4bc4-9d1a-5fc509021011

# %% [markdown]
# Use the run id to monitor the status of the new run. This will take another 10-15 min to run and will look similar to the previous pipeline run, so if you don't need to see another pipeline run, you can skip watching the full output.

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments["pipeline-rest-endpoint"], run_id)
RunDetails(published_pipeline_run).show()
# Out:
# _PipelineWidget(widget_settings={'childWidgetDisplay': 'popup', 'send_telemetry': False, 'log_level': 'INFO', …
